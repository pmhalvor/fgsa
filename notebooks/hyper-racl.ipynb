# %%
# %load_ext autoreload
# %autoreload 2

# for local imports
import sys
import os
sys.path.insert(0, os.getcwd().split('notebooks')[0])

# %%
from src.plot import show_study_loss
from src.plot import smooth

# %% [markdown]
# # After the great debugging
#
# Learning rate `1e-5` is the best, with only `1e-6` as a reasonable other.
# Can maybe decrease lr scheduler?
#
# CNN dimensions seems all reasonable. We have the exact same configurations in the first study get everywhere from .40 up to .449. So really, all the cnn dimensions are considered reasonable. Not worth further exploring for now.
#
#
# We see a definite decrease in performance as stack increases to 4, however, if this starts already at stack 1 is difficult to tell.
# At least 1 and 2 gave reasonable results.
# Will test one more of these w/ `[1,1,1,2,2,2,3,3,3]`.
#
#
# A part of me wants to run all of these again, just to get more data. But then again. We now have 8 runs of the same configs.
#
# ```
# > ((smooth_lr[1] + smooth_stack[1])/2)[20:]
#
# 	  absa	     hard	      binary	proportional	span	macro
# 20	0.449444	0.546363	0.589479	0.658272	0.924382	0.669562
# 21	0.451904	0.546375	0.589039	0.656137	0.923056	0.667299
# 22	0.448580	0.541952	0.590713	0.660536	0.923498	0.671661
# 23	0.449194	0.545335	0.590770	0.657001	0.922967	0.668377
# 24	0.454365	0.550489	0.591974	0.656350	0.922578	0.668073
# 25	0.442115	0.540081	0.568979	0.654577	0.923797	0.665839
# 26	0.438858	0.540714	0.569396	0.654223	0.923822	0.665422
#
# ```

# %%
# max(((4*smooth_lr[1] + 4*smooth_stack[1])/8)['absa'])
# # gives: 0.4554683523247893
# Out:
# 0.4554683523247893

# %%
# ((4*smooth_lr[1] + 4*smooth_stack[1])/8)[20:]
# Out:
#         absa      hard    binary  proportional      span     macro
# 20  0.449444  0.546363  0.589479      0.658272  0.924382  0.669562
# 21  0.451904  0.546375  0.589039      0.656137  0.923056  0.667299
# 22  0.448580  0.541952  0.590713      0.660536  0.923498  0.671661
# 23  0.449194  0.545335  0.590770      0.657001  0.922967  0.668377
# 24  0.454365  0.550489  0.591974      0.656350  0.922578  0.668073
# 25  0.442115  0.540081  0.568979      0.654577  0.923797  0.665839
# 26  0.438858  0.540714  0.569396      0.654223  0.923822  0.665422

# %% [markdown]
# # Learning rate

# %%
lr = show_study_loss("../log/2022-04-20/dev-racl-lr.log")
# Out:
# Metric:absa  Score:0.351557823787905  lr=0.0001 (study.py:285)
#
# Metric:absa  Score:0.3458350045688433  lr=0.0001 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'optimizer_name': 'adam', 'weight_decay': 0, 'lr': 0.0001} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4129463911800781  lr=1e-05 (study.py:285)
#
# Metric:absa  Score:0.4091804031865885  lr=1e-05 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'optimizer_name': 'adam', 'weight_decay': 0, 'lr': 1e-05} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.3858879898304005  lr=1e-06 (study.py:285)
#
# Metric:absa  Score:0.39369147270789845  lr=1e-06 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'optimizer_name': 'adam', 'weight_decay': 0, 'lr': 1e-06} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.0  lr=1e-07 (study.py:285)
#
# Metric:absa  Score:0.0  lr=1e-07 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'optimizer_name': 'adam', 'weight_decay': 0, 'lr': 1e-07} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4461925029773104  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.42858257271325656  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'optimizer_name': 'adam', 'weight_decay': 0, 'lr': 1e-05} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4443513934973765  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.4491833619085356  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'optimizer_name': 'adam', 'weight_decay': 0, 'lr': 1e-05} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.44133729024863627  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.4378067295028492  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'optimizer_name': 'adam', 'weight_decay': 0, 'lr': 1e-05} (study.py:226)
#
# ===========================================================================

# %%
smooth_lr = smooth(lr, [1, 4, 5, 6])
# Out:
# Final values:
#     expression  polarity    target
# 22    0.035446  0.009558  0.005417
# 23    0.024046  0.006652  0.007390
# 24    0.029792  0.003244  0.003128
#         absa      hard    binary  proportional      span     macro
# 24  0.450963  0.551716  0.588605      0.654967  0.922773  0.666763
# 25  0.436207  0.531913  0.565697      0.655561  0.925084  0.666212
# 26  0.431188  0.530932  0.565221      0.655978  0.924755  0.666577

# %% [markdown]
# # CNN dimensions

# %%
cnn_dim = show_study_loss("../log/2022-04-20/dev-racl-cnn-dim.log")
# Out:
# No data for run 0
# Metric:absa  Score:0.42474417405961173  cnn_dim=384 (study.py:285)
#
# Metric:absa  Score:0.4363512340846093  cnn_dim=384 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'cnn_dim': 384} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.43207268932340553  cnn_dim=768 (study.py:285)
#
# Metric:absa  Score:0.41445961058210257  cnn_dim=768 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'cnn_dim': 768} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.44245512643252677  cnn_dim=1536 (study.py:285)
#
# Metric:absa  Score:0.4306220234874966  cnn_dim=1536 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'cnn_dim': 1536} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4359649278905531  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.44505082661775414  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'cnn_dim': 384} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.43852619000214765  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.4355994562791777  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'cnn_dim': 384} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4211180741624802  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.43139851442446975  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'gold_transmission': True, 'stack_count': 1, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'cnn_dim': 384} (study.py:226)
#
# ===========================================================================

# %%
smooth_cnn_dim = smooth(cnn_dim, [1, 4,5,6])
# Out:
# Final values:
#     expression  polarity    target
# 22    0.032485  0.016506  0.010333
# 23    0.030162  0.008108  0.007250
# 24    0.023597  0.006441  0.005203
#         absa      hard    binary  proportional      span     macro
# 24  0.447633  0.542524  0.585851      0.658705  0.923786  0.668879
# 25  0.430088  0.531655  0.564455      0.660541  0.924779  0.670954
# 26  0.437100  0.538938  0.568810      0.660600  0.924476  0.671087

# %% [markdown]
# # Stack

# %%
stack = show_study_loss("../log/2022-04-20/dev-racl-stack.log")
# Out:
# Metric:absa  Score:0.4511023238996582  stack_count=1 (study.py:285)
#
# Metric:absa  Score:0.4519856299993864  stack_count=1 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'stack_count': 1} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4510428016454969  stack_count=2 (study.py:285)
#
# Metric:absa  Score:0.4440072151089767  stack_count=2 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'stack_count': 2} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4197335919164189  stack_count=3 (study.py:285)
#
# Metric:absa  Score:0.4157154864405748  stack_count=3 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'stack_count': 3} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.36599364532059664  stack_count=4 (study.py:285)
#
# Metric:absa  Score:0.37687834273790954  stack_count=4 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'stack_count': 4} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.45033557952938164  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.4360846557220343  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'stack_count': 1} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4332582991847338  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.443506225334529  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'stack_count': 1} (study.py:226)
#
# ===========================================================================
# Metric:absa  Score:0.4573932041198585  epochs=25 (study.py:285)
#
# Metric:absa  Score:0.45453125965674285  epochs=25 (study.py:285)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 25, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'gold_transmission': True, 'warm_up_constant': 5, 'dropout': 0.4, 'loss_weight': 1, 'lr': 1e-05, 'optimizer_name': 'adam', 'weight_decay': 0, 'stack_count': 1} (study.py:226)
#
# ===========================================================================

# %%
smooth_stack = smooth(stack, [0, 4,5,6])
# Out:
# Final values:
#     expression  polarity    target
# 22    0.027316  0.007990  0.005418
# 23    0.026847  0.004777  0.003037
# 24    0.023714  0.004077  0.002238
#         absa      hard    binary  proportional      span     macro
# 24  0.457767  0.549262  0.595342      0.657733  0.922383  0.669382
# 25  0.448022  0.548249  0.572261      0.653593  0.922510  0.665466
# 26  0.446527  0.550496  0.573572      0.652468  0.922888  0.664268
