# %%
# for local imports
import sys
import os
sys.path.insert(0, os.getcwd().split('notebooks')[0])

# %%
from src.plot import show_study_loss

# %% [markdown]
# # Stacks, weights, lrs

# %%
weight_tweens = show_study_loss("../log/2022-03-24/dev-RACL-weight-tweens.log")
# Out:
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 300, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'stack_count': 1, 'dropout': 0.4, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'loss_weight': 7} (study.py:224)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 300, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'stack_count': 1, 'dropout': 0.4, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'loss_weight': 9} (study.py:224)
# Above plots w/ following params:
# ...

# %%
show_study_loss("../log/2022-03-24/dev-RACL-stack.log")
None
# Out:
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 150, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'dropout': 0.4, 'loss_weight': 33, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'stack_count': 1} (study.py:224)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 150, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'dropout': 0.4, 'loss_weight': 33, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'stack_count': 2} (study.py:224)
# Above plots w/ following params:
# ...

# %%
show_study_loss("../log/2022-03-24/dev-RACL-lr.log")
None
# Out:
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 150, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'stack_count': 1, 'dropout': 0.4, 'loss_weight': 33, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'lr': 1e-08} (study.py:224)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 150, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'stack_count': 1, 'dropout': 0.4, 'loss_weight': 33, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'lr': 1e-07} (study.py:224)
# Above plots w/ following params:
# ...

# %%
show_study_loss("../log/2022-03-24/dev-RACL-weight.log")
None
# Out:
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 150, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'stack_count': 1, 'dropout': 0.4, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'loss_weight': 1} (study.py:224)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 150, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'stack_count': 1, 'dropout': 0.4, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-06, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'loss_weight': 10} (study.py:224)
# Above plots w/ following params:
# ...

# %% [markdown]
# # First day of RACL runs

# %%
show_study_loss("../log/2022-03-23/dev-racl.log")
None
# Out:
# No data for run 0
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 100, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'dropout': 0.4, 'loss_weight': 33, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-05, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'stack_count': 1} (study.py:221)
# Above plots w/ following params:
#   {'bert_path': 'ltgoslo/norbert2', 'debug': False, 'device': 'cuda', 'epochs': 100, 'ignore_id': -1, 'model_name': 'racl', 'cnn_dim': 768, 'dropout': 0.4, 'loss_weight': 33, 'bert_finetune': True, 'bert_polarity': True, 'bert_target': True, 'optimizer_name': 'adam', 'weight_decay': 0.5, 'lr': 1e-08, 'expression_lr': 1e-06, 'polarity_lr': 1e-05, 'target_lr': 1e-06, 'warm_up_constant': 5, 'find_scope': False, 'stack_count': 1} (study.py:223)
# ...
